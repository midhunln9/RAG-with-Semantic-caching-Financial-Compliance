# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/midhunln/streamingrag/offline_retriever_eval/GoldenDataset/dataset_chunks_queries/hundred_Chunks_with_Queries.csv"
)

# %%
df["generated_query"][15]
# Out:
# 'What are the specific requirements for submitting Form PAS-3, including the necessary details of security holders and the exceptions for non-banking financial companies and housing finance companies?'
